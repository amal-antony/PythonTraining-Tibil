# %% [markdown]
# ## Seaborn
# A visualization library build on top of matplotlib<br>
# Must be imported brfore use<br>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_style=("darkgrid")
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize']=10,6
import os
os.getcwd()
# Out:
# '/home/amal-baby-antony/Desktop/Tibil/Trainings/Python/Session_13'

# %%
demographic_data=pd.read_csv('/home/amal-baby-antony/Desktop/Tibil/Trainings/Python/Session_13/P4-Demographic-Data.csv')

# %%
demographic_data
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
demographic_data.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
demographic_data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
stats=demographic_data
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %% [markdown]
# ## 1. Distribution plot or distplot
# Also called bar chart<br>
# sns.distplot()<br>
# Has lot of Parameters that can be passed , First parameter is actual matrix<br>
#
# 1. bins=pieces of rectangular bars

# %%
sns.set(style="darkgrid")
sns.distplot(stats['Internet users'])
# Out:
# /home/amal-baby-antony/miniconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Internet users', ylabel='Density'>

# %%
sns.displot(stats['Internet users'])

# %%
sns.displot(stats['Internet users'],bins=30)

# %%
sns.displot(stats['Internet users'],bins=5)

# %% [markdown]
# ## Box Plot
# 1.A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across
# levels of a categorical variable. <br>
# 2.The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.<br>
#
# Has following main parameters
# 1. Dataframe name
# 2. x= categorical variable
# 3. y=
#
# 3.Distribution characteristics of a group of scores and level of them<br>
# 4.4 equal size groups each 25%<br>
# 5.Lines dividing groups are called quartiles

# %%
vis1=sns.boxplot(data=stats,x='Income Group',y='Birth rate')

# %% [markdown]
# ## LM plot or Linear model plot
# 1. A plot made from linear regression
# 2. Regression line can be viewed
# 3. To avoid regression line set the parameter
#       ### fit_reg=false
# 4.hue-Parameter for color- Just specify for what column in the dataframe we want to apply color

# %%
sns.lmplot(data=stats,x='Internet users',y='Birth rate')

# %%
sns.lmplot(data=stats,x='Internet users',y='Birth rate',fit_reg=False)

# %%
sns.lmplot(data=stats,x='Internet users',y='Birth rate',fit_reg=False,hue='Income Group')

# %%
sns.lmplot(data=stats,x='Internet users',y='Birth rate',fit_reg=False,hue='Income Group',size=8)
# Out:
# /home/amal-baby-antony/miniconda3/lib/python3.9/site-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### To increase size of the marker use dictionary scatter_kws and provide value for paramater s as the size we want

# %%
sns.lmplot(data=stats,x='Internet users',y='Birth rate',fit_reg=False,hue='Income Group',height=8,scatter_kws={"s":120})
